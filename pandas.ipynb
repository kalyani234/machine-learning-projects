# %%
import pandas as pd

# %%
data = [1,2,3,4]

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['c1','c2','c3'], index = ['r0','r1','r2'])

# %%
df
# Out:
#     c1  c2  c3
# r0   1   2   3
# r1   4   5   6
# r2   7   8   9

# %%
financial_data = pd.read_csv('./financial_loan.csv')

# %%
financial_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
financial_data.tail(5)
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE  11-07-2021
# 38572                        Swat Fame     C           RENT  11-10-2021
# 38573  Anaheim Regional Medical Center     D           RENT  11-09-2021
# 38574               Brooklyn Radiology     D           RENT  11-10-2021
# 38575                    Allen Edmonds     F           RENT  11-07-2021
#
#       last_credit_pull_date last_payment_date  ... sub_grade        term  \
# 38571            16-05-2021        16-05-2021  ...        C1   60 months
# ...

# %%
financial_data.sample()
# Out:
#            id address_state application_type emp_length emp_title grade  \
# 28819  591431            CA       INDIVIDUAL    2 years      dawn     A
#
#       home_ownership  issue_date last_credit_pull_date last_payment_date  ...  \
# 28819           RENT  10-10-2021            15-08-2021        13-10-2021  ...
#
#       sub_grade        term  verification_status annual_income     dti  \
# 28819        A3   36 months         Not Verified       14400.0  0.0317
#
#       installment int_rate  loan_amount  total_acc  total_payment
# 28819       37.13   0.0714         1200         10           1337
#
# [1 rows x 24 columns]

# %%
financial_data.sample(10)
# Out:
#            id address_state application_type emp_length  \
# 19870  696329            NV       INDIVIDUAL    9 years
# 37168  631926            GA       INDIVIDUAL    2 years
# 22455  593242            NY       INDIVIDUAL  10+ years
# 31060  870140            CA       INDIVIDUAL  10+ years
# 33810  527259            MA       INDIVIDUAL    6 years
# 37971  811320            NY       INDIVIDUAL   < 1 year
# 31091  432766            DE       INDIVIDUAL     1 year
# 26917  549671            FL       INDIVIDUAL    2 years
# 2455   424676            WA       INDIVIDUAL    5 years
# 32525  473891            PA       INDIVIDUAL    7 years
#
#                            emp_title grade home_ownership  issue_date  \
# 19870  Las Vegas Professional Hockey     C       MORTGAGE  11-03-2021
# 37168            Booz Allen Hamilton     G       MORTGAGE  10-12-2021
# 22455            ibew local union #3     B       MORTGAGE  10-10-2021
# ...

# %%
financial_data.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
financial_data.columns.to_list()
# Out:
# ['id',
#  'address_state',
#  'application_type',
#  'emp_length',
#  'emp_title',
#  'grade',
#  'home_ownership',
#  'issue_date',
#  'last_credit_pull_date',
#  'last_payment_date',
#  'loan_status',
#  'next_payment_date',
#  'member_id',
#  'purpose',
#  'sub_grade',
#  'term',
#  'verification_status',
#  'annual_income',
#  'dti',
#  'installment',
#  'int_rate',
#  'loan_amount',
#  'total_acc',
#  'total_payment']

# %%
financial_data.shape
# Out:
# (38576, 24)

# %%
financial_data.size
# Out:
# 925824

# %%
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
financial_data.loc[0,'address_state']
# Out:
# 'GA'

# %%
financial_data.loc[0:5,'address_state']
# Out:
# 0    GA
# 1    CA
# 2    CA
# 3    TX
# 4    IL
# 5    CA
# Name: address_state, dtype: object

# %%
financial_data.loc[0:5,['id','address_state', 'application_type']] # addd more than one column name
# Out:
#         id address_state application_type
# 0  1077430            GA       INDIVIDUAL
# 1  1072053            CA       INDIVIDUAL
# 2  1069243            CA       INDIVIDUAL
# 3  1041756            TX       INDIVIDUAL
# 4  1068350            IL       INDIVIDUAL
# 5  1062608            CA       INDIVIDUAL

# %%
# loc = label based

# %%
financial_data.loc[0:5,['id',
 'address_state',
 'application_type',
 'emp_length',
 'emp_title',
 'grade',
 'home_ownership']]
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
# 5  1062608            CA       INDIVIDUAL    3 years         Studio 94 Corp
#
#   grade home_ownership
# 0     C           RENT
# 1     E           RENT
# 2     C           RENT
# 3     B       MORTGAGE
# 4     A       MORTGAGE
# 5     C           RENT

# %%
# we can rewrite above script as: 
financial_data.loc[0:5,'id':'home_ownership']
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
# 5  1062608            CA       INDIVIDUAL    3 years         Studio 94 Corp
#
#   grade home_ownership
# 0     C           RENT
# 1     E           RENT
# 2     C           RENT
# 3     B       MORTGAGE
# 4     A       MORTGAGE
# 5     C           RENT

# %%
# To get all columns

financial_data.loc[:,'id':'home_ownership']
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership
# 0                                Ryder     C           RENT
# 1                       MKC Accounting     E           RENT
# 2                Chemat Technology Inc     C           RENT
# ...

# %%
# iloc - index postion

financial_data.iloc[0,1]
# Out:
# 'GA'

# %%
financial_data.iloc[0:3,1]
# Out:
# 0    GA
# 1    CA
# 2    CA
# Name: address_state, dtype: object

# %%
financial_data.iloc[0:3,0:5]
# Out:
#         id address_state application_type emp_length              emp_title
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc

# %%
financial_data.iloc[[330,335,400],0:5] # specify particular columns
# Out:
#          id address_state application_type emp_length  \
# 330  838960            WA       INDIVIDUAL     1 year
# 335  883995            FL       INDIVIDUAL  10+ years
# 400  356125            CA       INDIVIDUAL   < 1 year
#
#                                     emp_title
# 330                                CentrAlert
# 335  escambia county board of county commissi
# 400                Salamander Fire Protection

# %%
financial_data.at[0,'id'] # at - label
# Out:
# 1077430

# %%
financial_data.iat[0,0] # index position
# Out:
# 1077430

# %%
# Filtering data on specific conditions

# %%
financial_data.head(5)
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
financial_data.loc[financial_data['loan_amount'] > 30000]
# Out:
#             id address_state application_type emp_length  \
# 1494   1044500            NY       INDIVIDUAL  10+ years
# 1643   1056174            CO       INDIVIDUAL  10+ years
# 1679   1055282            MI       INDIVIDUAL     1 year
# 1699   1059319            CA       INDIVIDUAL    4 years
# 4020   1050226            CA       INDIVIDUAL    2 years
# ...        ...           ...              ...        ...
# 38477   981516            VA       INDIVIDUAL    5 years
# 38491   682280            PA       INDIVIDUAL    2 years
# 38500   822087            MD       INDIVIDUAL    4 years
# 38511   702589            NJ       INDIVIDUAL    2 years
# 38550   853145            NY       INDIVIDUAL    8 years
#
#                      emp_title grade home_ownership  issue_date  \
# 1494                      Nypd     F            OWN  11-12-2021
# 1643                  Visa Inc     A       MORTGAGE  11-12-2021
# 1679                       IBM     C       MORTGAGE  11-12-2021
# ...

# %%
financial_data.loc[(financial_data['loan_amount'] > 30000) & (financial_data['grade']=='F'),['loan_amount','grade']]
# Out:
#        loan_amount grade
# 1494         32000     F
# 5864         35000     F
# 5867         35000     F
# 5944         32000     F
# 6002         31500     F
# ...            ...   ...
# 36898        35000     F
# 37030        35000     F
# 37072        35000     F
# 37162        35000     F
# 37164        35000     F
#
# [106 rows x 2 columns]

# %%
# short hand notations

financial_data[(financial_data['loan_amount'] > 30000) & (financial_data['grade']=='F')]
# Out:
#             id address_state application_type emp_length  \
# 1494   1044500            NY       INDIVIDUAL  10+ years
# 5864    972576            IL       INDIVIDUAL     1 year
# 5867    767614            CA       INDIVIDUAL   < 1 year
# 5944    801737            FL       INDIVIDUAL  10+ years
# 6002    686989            OH       INDIVIDUAL    6 years
# ...        ...           ...              ...        ...
# 36898  1007174            AZ       INDIVIDUAL    3 years
# 37030   632417            UT       INDIVIDUAL    2 years
# 37072   733951            FL       INDIVIDUAL  10+ years
# 37162   748304            CA       INDIVIDUAL  10+ years
# 37164   711710            CA       INDIVIDUAL  10+ years
#
#                           emp_title grade home_ownership  issue_date  \
# 1494                           Nypd     F            OWN  11-12-2021
# 5864                          Wipro     F       MORTGAGE  11-10-2021
# 5867                     CHReynolds     F       MORTGAGE  11-06-2021
# ...

# %%
financial_data[financial_data['verification_status'].str.contains('Source')]
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 7      1066424            PA       INDIVIDUAL  10+ years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# ...        ...           ...              ...        ...
# 38566  1007647            VA       INDIVIDUAL     1 year
# 38567  1020423            GA       INDIVIDUAL   < 1 year
# 38568   792945            IL       INDIVIDUAL    3 years
# 38569   844956            VA       INDIVIDUAL    2 years
# 38570   841271            CT       INDIVIDUAL     1 year
#
#                                       emp_title grade home_ownership  \
# 0                                         Ryder     C           RENT
# 1                                MKC Accounting     E           RENT
# 3                           barnes distribution     B       MORTGAGE
# ...

# %%
financial_data['verification_status'].str.contains('Source').sum()
# Out:
# 9777

# %%
financial_data[financial_data['verification_status'].str.startswith('Source')]
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 7      1066424            PA       INDIVIDUAL  10+ years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# ...        ...           ...              ...        ...
# 38566  1007647            VA       INDIVIDUAL     1 year
# 38567  1020423            GA       INDIVIDUAL   < 1 year
# 38568   792945            IL       INDIVIDUAL    3 years
# 38569   844956            VA       INDIVIDUAL    2 years
# 38570   841271            CT       INDIVIDUAL     1 year
#
#                                       emp_title grade home_ownership  \
# 0                                         Ryder     C           RENT
# 1                                MKC Accounting     E           RENT
# 3                           barnes distribution     B       MORTGAGE
# ...

# %%
financial_data[financial_data['verification_status'].str.contains('Source')]
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 7      1066424            PA       INDIVIDUAL  10+ years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# ...        ...           ...              ...        ...
# 38566  1007647            VA       INDIVIDUAL     1 year
# 38567  1020423            GA       INDIVIDUAL   < 1 year
# 38568   792945            IL       INDIVIDUAL    3 years
# 38569   844956            VA       INDIVIDUAL    2 years
# 38570   841271            CT       INDIVIDUAL     1 year
#
#                                       emp_title grade home_ownership  \
# 0                                         Ryder     C           RENT
# 1                                MKC Accounting     E           RENT
# 3                           barnes distribution     B       MORTGAGE
# ...

# %%
financial_data.loc[:2,'grade']='A'

# %%
financial_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     A           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     A           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     A           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
financial_data.loc[:2,'grade']='A'

# %%
# iloc - index position
financial_data.iloc[:2,1]='IL'

# %%
financial_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            IL       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            IL       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     A           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     A           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     A           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
# at and iat for single values 

financial_data.at[:3,'address_state']= 'IL'

# %%
financial_data.iat[2,1]= 'WA'

# %%
financial_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            IL       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            IL       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            WA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            IL       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     A           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     A           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     A           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
def increment_total_acc(x):
    return x+10
financial_data['total_acc'] = financial_data['total_acc'].apply(increment_total_acc)
financial_data['total_acc']
# Out:
# 0        14
# 1        14
# 2        21
# 3        19
# 4        38
#          ..
# 38571    43
# 38572    28
# 38573    30
# 38574    19
# 38575    17
# Name: total_acc, Length: 38576, dtype: int64

# %%
financial_data['total_acc'] = financial_data['total_acc'].apply(lambda x:x-5)
financial_data['total_acc']
# Out:
# 0         9
# 1         9
# 2        16
# 3        14
# 4        33
#          ..
# 38571    38
# 38572    23
# 38573    25
# 38574    14
# 38575    12
# Name: total_acc, Length: 38576, dtype: int64

# %%
financial_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            IL       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            IL       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            WA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            IL       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     A           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     A           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     A           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
financial_data['loan_status']=financial_data['annual_income'].apply(lambda x: 'Approved' if x> 50000.0 else 'Not Approved')

# %%
financial_data.columns.to_list()
# Out:
# ['id',
#  'address_state',
#  'application_type',
#  'emp_length',
#  'emp_title',
#  'grade',
#  'home_ownership',
#  'issue_date',
#  'last_credit_pull_date',
#  'last_payment_date',
#  'loan_status',
#  'next_payment_date',
#  'member_id',
#  'purpose',
#  'sub_grade',
#  'term',
#  'verification_status',
#  'annual_income',
#  'dti',
#  'installment',
#  'int_rate',
#  'loan_amount',
#  'total_acc',
#  'total_payment']

# %%
financial_data.loc[0:10,['id','annual_income','loan_status']]
# Out:
#          id  annual_income   loan_status
# 0   1077430        30000.0  Not Approved
# 1   1072053        48000.0  Not Approved
# 2   1069243        50000.0  Not Approved
# 3   1041756        42000.0  Not Approved
# 4   1068350        83000.0      Approved
# 5   1062608        28000.0  Not Approved
# 6   1067441        94800.0      Approved
# 7   1066424        59000.0      Approved
# 8   1065254       116400.0      Approved
# 9   1064589        36000.0  Not Approved
# 10  1057766        75000.0      Approved
